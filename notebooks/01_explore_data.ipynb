# %% [markdown]
# # 01 Explore Data
# Lecture d'un GeoTIFF, aperçu des valeurs, et vecteur→raster.

# %%
import rasterio, json, numpy as np
from rasterio.plot import show
from src.geo.io import read_geotiff
print('Déposez vos données sous data/raw/...')
