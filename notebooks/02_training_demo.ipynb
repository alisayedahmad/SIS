# %% [markdown]
# # 02 Training Demo
# Démonstration d'entraînement rapide sur un subset de tuiles.

# %%
from lightning.pytorch import Trainer
from src.cli.train import main
print('Utilisez les configs sous configs/*.yaml')
